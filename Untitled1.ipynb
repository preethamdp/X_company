# %%
from pandas import read_csv,DataFrame

# %%
df = read_csv("phbook.csv")
print("shape",df.shape)
df.head()
# Out:
# shape (3291, 7)
#    Unnamed: 0 search-city            search-key  \
# 0           0      Mumbai  textile-manufacturer
# 1           1      Mumbai  textile-manufacturer
# 2           2      Mumbai  textile-manufacturer
# 3           3      Mumbai  textile-manufacturer
# 4           4      Mumbai  textile-manufacturer
#
#                                              company              phno  \
# 0                      Mihir Tex in Bhiwandi, Mumbai  +(91)-9152288628
# 1               S K Trading Co in Malad West, Mumbai  +(91)-7977306951
# 2  Sri Kalyan Export Pvt Ltd in Villarasampatti, ...  +(91)-8220999953
# 3     Pixel Clothings in Opp Deepa Hospital, Tirupur  +(91)-9566650876
# 4      Walrus SEER Textile MILLS in Pn Road, Tirupur  +(91)-9843077722
#
#                                       actual-address  \
# 0  309, Vardhman Arcade,, Bhiwandi Wada Road, Bhi...
# 1  31, Malad Shopping Centre, 1st Floor, Malad We...
# 2  192/4 Iswarya Garden, Villarasampatti, Erode -...
# ...

# %%
df.groupby(["phno"]).groups
# Out:
# {'+(91)-011-22438145': Int64Index([619], dtype='int64'),
#  '+(91)-011-23261611': Int64Index([777], dtype='int64'),
#  '+(91)-011-23270268': Int64Index([782], dtype='int64'),
#  '+(91)-011-23280706': Int64Index([561], dtype='int64'),
#  '+(91)-011-23282530': Int64Index([595], dtype='int64'),
#  '+(91)-011-23322860': Int64Index([602], dtype='int64'),
#  '+(91)-011-23325012': Int64Index([560], dtype='int64'),
#  '+(91)-011-23586584': Int64Index([610], dtype='int64'),
#  '+(91)-011-23613554': Int64Index([798], dtype='int64'),
#  '+(91)-011-23926808': Int64Index([650], dtype='int64'),
#  '+(91)-011-23935276': Int64Index([655], dtype='int64'),
#  '+(91)-011-23953417': Int64Index([778], dtype='int64'),
#  '+(91)-011-25250829': Int64Index([680], dtype='int64'),
#  '+(91)-011-25411708': Int64Index([699], dtype='int64'),
#  '+(91)-011-25731396': Int64Index([714], dtype='int64'),
#  '+(91)-011-25778582': Int64Index([588], dtype='int64'),
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (3290, 7)

# %%
df.to_csv("phbook.csv")

# %%
df = df[['search-city', 'search-key', 'company', 'phno',
       'actual-address', 'actual-tags']]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'search-city', 'search-key', 'company', 'phno',
#        'actual-address', 'actual-tags'],
#       dtype='object')
